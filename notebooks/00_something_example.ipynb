# %% [markdown]
# # 00 — Példa notebook (setup sablon)
#
# Ez a notebook csak a közös setup-ot mutatja: Colab/lokális környezet-detektálás, repo klónozás, `src/` import. Minden új notebook ezzel a két cellával induljon.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Slityak/gepitan-seoul-bike-trip/blob/main/notebooks/00_something_example.ipynb)

# %% [markdown]
# ## 1. Setup

# %%
import os
import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

    if not os.path.exists('/content/gepitan-beadando'):
        # !git clone https://github.com/Slityak/gepitan-seoul-bike-trip.git /content/gepitan-beadando

    os.chdir('/content/gepitan-beadando')
    # !git pull
    # !pip install -q -r requirements.txt
else:
    if os.path.basename(os.getcwd()) == 'notebooks':
        os.chdir('..')

sys.path.insert(0, '.')
print(f'Working dir: {os.getcwd()}')
print(f'In Colab: {IN_COLAB}')

# %% [markdown]
# ## 2. Importok
#
# A közös util-ok a `src/` alól jönnek. Az `ensure_dirs()` létrehozza a `models/`, `results/`, `results/figures/` mappákat ha még nincsenek.

# %%
import numpy as np

from src.config import RANDOM_SEED, CV_FOLDS, MODELS_DIR, FIGURES_DIR, ensure_dirs
from src.data_io import load_train_test

ensure_dirs()
print(f'Random seed: {RANDOM_SEED}')

# %% [markdown]
# ## 3. Innen jön a saját kód
#
# _Adatbetöltés, modell, kiértékelés, vizualizációk_
